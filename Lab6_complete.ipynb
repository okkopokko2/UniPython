# %% [markdown]
# <a href="https://colab.research.google.com/github/okkopokko2/UniPython/blob/main/Lab6_complete.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#lab6Homework
#task1


class Student:
  ID=0
  def __init__(self,name,dept,age,cgpa):
    Student.ID+=1
    self.name=name
    self.dept=dept
    self.age=age
    self.cgpa=cgpa

  def showDetails(self):
    print(f"ID: {Student.ID}")
    print(f'Name: {self.name}')
    print(f'Department: {self.dept}')
    print(f'Age: {self.age}')
    print(f'CGPA: {self.cgpa}')


  @classmethod
  def from_String(self,j):
    x=j.split("-")

    y=Student(x[0],x[1],x[2],x[3])

    return y






s1 = Student("Samin", "CSE", 21, 3.91)
s1.showDetails()
print("-----------------------")
s2 = Student("Fahim", "ECE", 21, 3.85)
s2.showDetails()
print("-----------------------")
s3 = Student("Tahura", "EEE", 22, 3.01)
s3.showDetails()
print("-----------------------")
s4 = Student.from_String("Sumaiya-BBA-23-3.96")
s4.showDetails()
# Out:
# ID: 1
# Name: Samin
# Department: CSE
# Age: 21
# CGPA: 3.91
# -----------------------
# ID: 2
# Name: Fahim
# Department: ECE
# Age: 21
# CGPA: 3.85
# -----------------------
# ID: 3
# Name: Tahura
# Department: EEE
# Age: 22
# CGPA: 3.01
# -----------------------
# ID: 4
# Name: Sumaiya
# Department: BBA
# Age: 23
# CGPA: 3.96

# %%
#task2


class Passenger:
    count=0
    def __init__(self,name):
        self.name=name
        self.busfare=450
        Passenger.count+=1

    def set_bag_weight(self, x):
        if x > 50:
            self.busfare += 100

        elif x < 21:
            self.busfare +=0

        elif x>21 and x<= 50:
            self.busfare +=50



    def printDetail(self):
        print(f'Name: {self.name}\nBus Fare:{self.busfare}')










print("Total Passenger:", Passenger.count)
p1 = Passenger("Jack")
p1.set_bag_weight(90)
p2 = Passenger("Carol")
p2.set_bag_weight(10)
p3 = Passenger("Mike")
p3.set_bag_weight(25)
print("=========================")
p1.printDetail()
print("=========================")
p2.printDetail()
print("=========================")
p3.printDetail()
print("=========================")
print("Total Passenger:", Passenger.count)
# Out:
# Total Passenger: 0
# ...
# Name: Jack
# Bus Fare:550
# ...
# Name: Carol
# Bus Fare:450
# ...
# Name: Mike
# Bus Fare:500
# ...
# Total Passenger: 3

# %%
#task3

class Travel:
  count=0
  def __init__(self,source,destination):
    self.source=source
    self.destination=destination
    Travel.count+=1
    self.time=1


  def display_travel_info(self):
    return (f"Source:{self.source}\nDestination:{self.destination}\nFlight Time:{self.time}:00")

  def set_time(self,time):
    self.time=time

  def set_source(self,source):
    self.source=source

  def set_destination(self,desti):
    self.destination=desti










print("No. of Traveller =", Travel.count)
print("=======================")
t1 = Travel("Dhaka","India")
print(t1.display_travel_info())
print("=======================")
t2 = Travel("Kuala Lampur","Dhaka")
t2.set_time(23)
print(t2.display_travel_info())
print("=======================")
t3 = Travel("Dhaka","New_Zealand")
t3.set_time(15)
t3.set_destination("Germany")
print(t3.display_travel_info())
print("=======================")
t4 = Travel("Dhaka","India")
t4.set_time(9)
t4.set_source("Malaysia")
t4.set_destination("Canada")
print(t4.display_travel_info())
print("=======================")
print("No. of Traveller =", Travel.count)
# Out:
# No. of Traveller = 0
# ...
# Source:Dhaka
# Destination:India
# Flight Time:1:00
# ...
# Source:Kuala Lampur
# Destination:Dhaka
# Flight Time:23:00
# ...
# Source:Dhaka
# Destination:Germany
# Flight Time:15:00
# ...
# Source:Malaysia
# Destination:Canada
# Flight Time:9:00
# ...
# No. of Traveller = 4

# %%
#task4Lab6

class NikeBangladesh:
    branches=0
    totalinventory={'Air Jordan': 0, 'Cortez': 0, 'Zoom Kobe': 0}
    brancheslocation=[]
    totalsold=0
    def __init__(self,location):
        self.location=location
        NikeBangladesh.branches+=1
        NikeBangladesh.brancheslocation.append(self.location)
        self.branchsold=0
        self.branchinventory={'Air Jordan': 0, 'Cortez': 0, 'Zoom Kobe': 0}



    @classmethod
    def status(cls):
        print("Nike Bangladesh Status:")
        print(f"Branches Opened: {NikeBangladesh.brancheslocation}")
        print("Current Stokced")
        print(NikeBangladesh.totalinventory)
        print(NikeBangladesh.totalsold)

    def details(self):
        print(f"Nike {self.location} outlet:")
        print("Products Currently Stocked:")
        print(self.branchinventory)
        print(self.branchsold)

    def restockProducts(self,x):

        for i in self.branchinventory.keys():
            for j,k in x.items():
                if i==j:
                    self.branchinventory[i]+=k

                else:
                    continue

        for i in NikeBangladesh.totalinventory:
            for j,k in x.items():
                if i==j:
                    NikeBangladesh.totalinventory[i]+=k

                else:
                    continue

    def productSold(self,y):

        for i in NikeBangladesh.totalinventory.keys():
            for j,k in y.items():
                if i==j:
                    NikeBangladesh.totalinventory[i]-=k
                    NikeBangladesh.totalsold += k

                else:
                    continue





print("xxxxxxxxxxxxxx1xxxxxxxxxxxxxxxx")
NikeBangladesh.status()
dhaka = NikeBangladesh("Dhaka Banani")
chittagong = NikeBangladesh("Chittagong GEC")
print("xxxxxxxxxxxxxx2xxxxxxxxxxxxxxxx")
dhaka.details()
print("xxxxxxxxxxxxxx3xxxxxxxxxxxxxxxx")
chittagong.details()
print("xxxxxxxxxxxxxx4xxxxxxxxxxxxxxxx")
dhaka.restockProducts(
{"Air Jordan":1200,"Cortez":200,"Zoom Kobe":200})
chittagong.restockProducts(
{"Air Jordan":1000,"Cortez":250,"Zoom Kobe":100})
print("xxxxxxxxxxxxxx5xxxxxxxxxxxxxxxx")
NikeBangladesh.status()
print("xxxxxxxxxxxxxx6xxxxxxxxxxxxxxxx")
dhaka.productSold({"Air Jordan":760,"Cortez":90})
chittagong.productSold({"Air Jordan":520,"Zoom Kobe":70})
print("xxxxxxxxxxxxxx7xxxxxxxxxxxxxxxx")
NikeBangladesh.status()

# %%
#task5

class Student:
    totalstudent=0
    bracstudent=0
    otherstudent=0
    def __init__(self,name,dept,ins=None):
        self.name=name
        self.dept=dept
        self.ins=ins
        Student.totalstudent+=1

        if self.ins==None:
            Student.bracstudent+=1

        else:
            Student.otherstudent+=1


    def individualDetail(self):
        if self.ins==None:
            print(f"Name: {self.name}")
            print(f"Department: {self.dept}")
            print("Institution: BRAC University")

        else:
            print(f"Name: {self.name}")
            print(f"Department: {self.dept}")
            print(f"Institution: {self.ins}")

    @classmethod
    def printDetails(cls):
        print(F"Total Student(s): {cls.totalstudent}")
        print(f"BRAC University Student(s): {cls.bracstudent}")
        print(f"Other Institution Student(s): {cls.otherstudent}")



    @classmethod
    def createStudent(cls,name,dept,uni=None):
        x=Student(name,dept,uni)
        return x






Student.printDetails()
print('#########################')
mikasa = Student('Mikasa Ackerman', "CSE")
mikasa.individualDetail()
print('------------------------------------------')
Student.printDetails()
print('========================')
harry = Student.createStudent('Harry Potter', "Defence Against DarkArts", "Hogwarts School")
harry.individualDetail()
print('-------------------------------------------')
Student.printDetails()
print('=========================')
levi = Student.createStudent("Levi Ackerman", "CSE")
levi.individualDetail()
print('--------------------------------------------')
Student.printDetails()

# %%
#task6









class SultansDine:
    totalbranches=0
    totalsell=0
    branchlist=[]
    def __init__(self,location):
        self.location=location
        SultansDine.totalbranches+=1
        self.sell=0
        SultansDine.branchlist.append(self)


    def sellQuantity(self,amount):
        if amount>20:
            self.sell+=(amount)*400
            SultansDine.totalsell+=(amount)*400

        elif amount>10 and amount <20:
            self.sell+=(amount)*350
            SultansDine.totalsell += (amount) * 350

        elif amount<10:
            self.sell += (amount) * 300
            SultansDine.totalsell += (amount) * 300

    def branchInformation(self):
        print(f"Branch Name: {self.location}")
        print(f"Branch Sell: {self.sell} Taka")


    @classmethod
    def details(cls):
        if len(SultansDine.branchlist)<1:
            print(f"Total Number of branche(s): {SultansDine.totalbranches}")
            print(f"Total Sell: {SultansDine.totalsell} Taka")

        else:
            print(f"Total Number of branche(s): {SultansDine.totalbranches}")
            print(f"Total Sell: {SultansDine.totalsell}")
            for i in SultansDine.branchlist:
                print(f"Branch Name: {i.location}, Branch Sell: {i.sell}, Branch consists of total sell's: {(i.sell/SultansDine.totalsell)*100}%")











SultansDine.details()
print('########################')
dhanmondi = SultansDine('Dhanmondi')
dhanmondi.sellQuantity(25)
dhanmondi.branchInformation()
print('-----------------------------------------')
SultansDine.details()
print('========================')
baily_road = SultansDine('Baily Road')
baily_road.sellQuantity(15)
baily_road.branchInformation()
print('-----------------------------------------')
SultansDine.details()
print('========================')
gulshan = SultansDine('Gulshan')
gulshan.sellQuantity(9)
gulshan.branchInformation()
print('-----------------------------------------')
SultansDine.details()
# Out:
# Total Number of branche(s): 0
# Total Sell: 0 Taka
# ########################
# Branch Name: Dhanmondi
# Branch Sell: 10000 Taka
# -----------------------------------------
# Total Number of branche(s): 1
# Total Sell: 10000
# Branch Name: Dhanmondi, Branch Sell: 10000, Branch consists of total sell's: 100.0%
# ...
# Branch Name: Baily Road
# Branch Sell: 5250 Taka
# -----------------------------------------
# Total Number of branche(s): 2
# Total Sell: 15250
# Branch Name: Dhanmondi, Branch Sell: 10000, Branch consists of total sell's: 65.57377049180327%
# Branch Name: Baily Road, Branch Sell: 5250, Branch consists of total sell's: 34.42622950819672%
# ...
# Branch Name: Gulshan
# Branch Sell: 2700 Taka
# -----------------------------------------
# Total Number of branche(s): 3
# Total Sell: 17950
# Branch Name: Dhanmondi, Branch Sell: 10000, Branch consists of total sell's: 55.71030640668524%
# Branch Name: Baily Road, Branch Sell: 5250, Branch consists of total sell's: 29.247910863509752%
# ...
