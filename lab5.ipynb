# %% [markdown]
# <a href="https://colab.research.google.com/github/okkopokko2/UniPython/blob/main/lab5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#lab 5
#task1
import math

class Circle:
  def __init__ (self,radius=None):
    self.__radius=radius
    self.jhontu=0

  def getRadius(self): #je variable ta private seta amra get function diye acces korte partesi
    #self.jhontu=self.__radius
    return self.__radius

  def setRadius(self,newradius): #je varibale ta private seta ke assign kora setfunction r kaj
     self.__radius=newradius


  def area(self):
    area=(math.pi)*(self.__radius**2)
    return area



c1 = Circle(4)
print("First circle radius:" , c1.getRadius())
print("First circle area:" , c1.area())


c2 = Circle(5)
print("Second circle radius:" , c2.getRadius())
print("Second circle area:" , c2.area())

# c3 = Circle()
# c3.setRadius(5)
# print("Second circle radius:" , c3.getRadius())
# print("Second circle area:" , c3.area())
# Out:
# First circle radius: 4
# First circle area: 50.26548245743669
# Second circle radius: 5
# Second circle area: 78.53981633974483

# %%
#task2

class Triangle:
  def __init__ (self,base=None,height=None):
    self.__base=base
    self.__height=height


  def getBase(self):
    return self.__base

  def getHeight(self):
    return self.__height

  def area(self):
    area=.5*(self.__base*self.__height)
    return area

  def setBase(self,base):
    self.__base=base #ei value ta construtcor e chole jabe then abr upor theke code run hoye niche porjonto ashbe

  def setHeight(self,height):
    self.__height=height #ei value ta construtcor e chole jabe then abr upor theke code run hoye niche porjonto ashbe






t1 = Triangle(10, 5)
print("First Triangle Base:" , t1.getBase())
print("First Triangle Height:" , t1.getHeight())
print("First Triangle area:" ,t1.area())


t2 = Triangle(5, 3)
print("Second Triangle Base:" , t2.getBase())
print("Second Triangle Height:" , t2.getHeight())
print("Second Triangle area:" ,t2.area())

# t3 = Triangle()
# t3.setBase(4)
# t3.setHeight(5)
# print("Second Triangle Base:" , t3.getBase())
# print("Second Triangle Height:" , t3.getHeight())
# print("Second Triangle area:" ,t3.area())

#t3.setBase(4)
#t3.setHeight(5)
# Out:
# First Triangle Base: 10
# First Triangle Height: 5
# First Triangle area: 25.0
# Second Triangle Base: 5
# Second Triangle Height: 3
# Second Triangle area: 7.5

# %%
#task3

class Teacher:
  def __init__ (self,name,dept):
    self.__name=name
    self.__dept=dept
    self.list1=[]


  def getName(self):
    return self.__name

  def setName(self,newName):
    self.__name=newName

  def getDept(self):
    return self.__dept

  def setDept(self,newDept):
    self.__dept=newDept

  def getList(self):
    return self.__list1
  def setList(self,newlist):
    self.list1=newlist

  def addCourse(self,course):
    self.list1.append(course.bal)


  def printDetail(self):
    print("====================================")
    print(f'Name: {self.__name}')
    print(f'Department: {self.__dept}')
    print('List of courses')
    print("====================================")
    for i in self.list1:
      print(i)
    print("====================================")

class Course:
    def __init__ (self,bal):
      self.bal=bal


t1 = Teacher("Saad Abdullah", "CSE")
t2 = Teacher("Mumit Khan", "CSE")
t3 = Teacher("Sadia Kazi", "CSE")
c1 = Course("CSE 110 Programming Language I")
c2 = Course("CSE 111 Programming Language-II")
c3 = Course("CSE 220 Data Structures")
c4 = Course("CSE 221 Algorithms")
c5 = Course("CSE 230 Discrete Mathematics")
c6 = Course("CSE 310 Object Oriented Programming")
c7 = Course("CSE 320 Data Communications")
c8 = Course("CSE 340 Computer Architecture")
t1.addCourse(c1)
t1.addCourse(c2)
t2.addCourse(c3)
t2.addCourse(c4)
t2.addCourse(c5)
t3.addCourse(c6)
t3.addCourse(c7)
t3.addCourse(c8)
t1.printDetail()
t2.printDetail()
t3.printDetail()
# Out:
# ...
# Name: Saad Abdullah
# Department: CSE
# List of courses
# ...
# CSE 110 Programming Language I
# CSE 111 Programming Language-II
# ...
# Name: Mumit Khan
# Department: CSE
# List of courses
# ...
# CSE 220 Data Structures
# CSE 221 Algorithms
# CSE 230 Discrete Mathematics
# ...
# Name: Sadia Kazi
# Department: CSE
# List of courses
# ...
# CSE 310 Object Oriented Programming
# CSE 320 Data Communications
# CSE 340 Computer Architecture
# ...

# %%
#task4
class Team:
  def __init__(self,country=None):
    self.__country=country
    self.list1=[]


  def setName(self,desh):
    self.desh=desh
    self.__country=self.desh

  #def printDetail(self):
    #print()

  def addPlayer(self,reference):
   self.list1.append(reference.name)


  def printDetail(self):
    print('=====================')
    print(f'Team:{self.__country}')
    print(f'List of players\n{self.list1}')
    print('=====================')


class Player:
  def __init__(self,name):
    self.name=name
    self.list2=[]


b = Team()
b.setName('Bangladesh')
mashrafi = Player("Mashrafi")
b.addPlayer(mashrafi)
tamim = Player("Tamim")
b.addPlayer(tamim)
b.printDetail()
a = Team("Australia")
ponting = Player("Ponting")
a.addPlayer(ponting)
lee = Player("Lee")
a.addPlayer(lee)
a.printDetail()
# Out:
# ...
# Team:Bangladesh
# List of players
# ['Mashrafi', 'Tamim']
# ...
# Team:Australia
# List of players
# ['Ponting', 'Lee']
# ...

# %%
#task5

class Student:
  def __init__(self,name,id,dept,email=None,password=None,login=None):
    print('Student object is created!')
    self.name=name
    self.id=id
    self.dept=dept
    self.email=email
    self.password=password
    self.login=login
    self.loginstat=False



class Usis:
  def __init__(self):
    self.list1=[]
    self.loginstat=False
    print("USIS is ready to use")

  def login(self,reference):
    if reference.email!=None and reference.password!=None:
      self.loginstat=True
      print('Login successful!')

    else:
      print('Please login to advise courses!')


  def advising(self,reference,*args):
    if self.loginstat==False:
      print('Please login to advise courses!')

    elif self.loginstat==True and len(args)<1:
        print("You haven't selected any courses.")

    elif self.loginstat==True and len(args)>3:
      print('You need special approval to take more than 3 courses')

    elif self.loginstat==True and len(args)==3:
      self.list1=list(args)
      print('Advising successful!')

  def individualDetails(self,reference):
    return(f'Name: {reference.name}\nDepartment: {reference.dept}\nAdvised course: {",".join(self.list1)}')
    #print(f'ID: {reference.id}')
    #print(f'Department: {reference.dept}')
    #print(f'Advised course:{self.list1}')








rakib = Student("Rakib", 12301455, "CSE")
print("1***********************")
usis_obj = Usis()
print("2***********************")
usis_obj.login(rakib)
print("3***********************")
usis_obj.advising(rakib)
print("4***********************")
rakib.email = "rakib@hotmail.com"
rakib.password = "1234"
print("5***********************")
usis_obj.login(rakib)
print("6***********************")
usis_obj.advising(rakib)
print("7***********************")
usis_obj.advising(rakib, "CSE110", "PHY111", "MAT110", "CSE260")
print("8***********************")
usis_obj.advising(rakib, "CSE110", "PHY111", "MAT110")
print("9***********************")
print(usis_obj.individualDetails(rakib))
# Out:
# Student object is created!
# 1***********************
# USIS is ready to use
# 2***********************
# Please login to advise courses!
# 3***********************
# 4***********************
# 5***********************
# Login successful!
# 6***********************
# You haven't selected any courses.
# 7***********************
# You need special approval to take more than 3 courses
# 8***********************
# Advising successful!
# 9***********************
# Name: Rakib
# Department: CSE
# Advised course: CSE110,PHY111,MAT110

# %%
#task6


class Train:
  #numberOfTrains=0

  def __init__(self,name,*args):
    self.name=name
    self.args=args
    self.obj=[]
    self.des=[]
    #Train.numberOfTrains+=1


    print(f'Welcome aboard on {self.name}')
    print(f'Start: {self.args[0]}')
    print(f'Destination: {self.args[len(self.args)-1]}')
    self.des+=list(args)
    print(self.des)

  def addPassenger(self,*reference):
    #self.obj=[]
    self.reference=reference
    #self.obj=[]
    self.obj+=list(reference)
    if len(self.reference)<2:
      print(f'{self.reference[0].name} welcome aboard')

    elif len(self.reference)==2:
      print(f'{self.reference[0].name} welcome aboard')
      print(f'{self.reference[1].name} welcome aboard')
      #print(f'{self.reference[2].name} welcome aboard')

    else:
      print(f'{self.reference[0].name} welcome aboard')
      print(f'{self.reference[1].name} welcome aboard')
      print(f'{self.reference[2].name} welcome aboard')


  def numberOfTrains(self):
    return Train.numberOfTrains

  def allPassengerDetails(self):
    #a=Passenger(self)
    l=len(self.des)
    end2=self.des[l-1]
    start=''
    end=''
    start2=''
    end2=''
    fair1=0
    fair2=0
    fair3=0

    # for i in self.des:
    #   for j in self.obj:
    #     if self.obj[j].start==None and self.obj[j].end==None:
    #       fair




    for i in range(len(self.obj)):
      for j in range(len(self.des)):

        if self.obj[i].start!=None and self.obj[i].end!=None : #hinata
          for k in self.des:
            if k==self.obj[i].start:
              start=k
              break

          for l in self.des:
            if l==self.obj[i].end:
              end=l
              break

          for m in range(len(self.des)):
            if self.des[m]==self.obj[i].start:
              x=self.des[m:len(self.des)]

          for n in range(len(x)):
            if x[n]==end:
              break

            else:
              fair3+=100

          print(f'Name: {self.obj[i].name}, Start: {start},Destination:{end},Fair:${fair3}')
          break

        elif self.obj[i].start!=None and self.obj[i].end==None and self.obj[i].start==self.des[j]: #sasuke
          for f in range(len(self.des)):
            if self.des[f]==self.obj[i].start:
              start2=self.des[f:len(self.des)]

          for g in start2:
            if g==start2[-1]:
              break

            else:
              fair2+=100


          print(f'Name: {self.obj[i].name}, Start: {self.des[j]},Destination: {end2},Fair:${fair2}')
          fair2=0
          break

        elif self.obj[i].start==None and self.obj[i].end==None: #naruto
          start2=self.des[0]
          end2=self.des[-1]

          for e in range(len(self.des)):
            if self.des[e]==end2:
              break
            else:
              fair1+=100
          print(f'Name: {self.obj[i].name}, Start: {self.des[j]},Destination:{end2},Fare:${fair1}')
          fair1=0
          break


    l=0
    self.des=[]
    self.obj=[]




class Passenger:
  #numberOfPassenger=0
  def __init__(self,name,start=None,end=None):
    #self.desti=desti
    self.name=name
    self.start=start
    self.end=end
    #Passenger.numberOfPassenger+=1
    #print(f'{self.name} welcome abroad')

  #def numberOfPassenger(self):

    #return Passenger.numberOfPassenger


t1 = Train('T1-Express','New York','Manhattan','Brooklyn','Boston')
print("1========================")
p1 =Passenger("Naruto")
t1.addPassenger(p1)
p2 = Passenger("Sasuke","Manhattan")
p3 = Passenger("Hinata","Manhattan","Brooklyn")
print("2========================")
t1.addPassenger(p2,p3)
print("3========================")
t1.allPassengerDetails()
print("4========================")
t2 = Train('Europe-Express','London','Paris','Brussels','Turkey')
print("5========================")
p4 =Passenger("Max","London","Brussels")
p5 = Passenger("Eleven","Paris")
p6 = Passenger("Mike","Brussels")
t2.addPassenger(p4,p5,p6)
print("6========================")
t2.allPassengerDetails()
# Out:
# Welcome aboard on T1-Express
# Start: New York
# Destination: Boston
# ['New York', 'Manhattan', 'Brooklyn', 'Boston']
# 1========================
# Naruto welcome aboard
# 2========================
# Sasuke welcome aboard
# Hinata welcome aboard
# 3========================
# Name: Naruto, Start: New York,Destination:Boston,Fare:$300
# Name: Sasuke, Start: Manhattan,Destination: Boston,Fair:$200
# Name: Hinata, Start: Manhattan,Destination:Brooklyn,Fair:$100
# 4========================
# Welcome aboard on Europe-Express
# Start: London
# Destination: Turkey
# ['London', 'Paris', 'Brussels', 'Turkey']
# 5========================
# Max welcome aboard
# Eleven welcome aboard
# Mike welcome aboard
# 6========================
# Name: Max, Start: London,Destination:Brussels,Fair:$200
# Name: Eleven, Start: Paris,Destination: ,Fair:$200
# Name: Mike, Start: Brussels,Destination: ,Fair:$100

# %%
a=['New York','Manhattan','Brooklyn','Boston']

start="Manhattan"
end="Brooklyn"
fair=0
for i in range(len(a)):
  if a[i]==start:
    b=a[i:len(a)]

for e in range(len(b)):
  if b[e]==end:
    break

  else:
    fair+=100

# for i in a:
#   if i==end:
#     break

#   else:
#     fair+=100


print(b)
print(fair)
# Out:
# ['Manhattan', 'Brooklyn', 'Boston']
# 100

# %%
a=['London','Paris','Brussels','Turkey']
fair1=0
fair2=0
fair3=0
suru=''
sesh=''
for i in a:
  if i!='Boston':
    fair1+=100

for i in a:
  if i



print(fair1)
# Out:
# 300

# %%
a=['New York', 'Manhattan', 'Brooklyn', 'Boston']

print(a[-1])
# Out:
# Boston

# %%
#task7

class BracuStudent:
  def __init__(self,name,des):
    self.name=name
    self.des=des

  def show_details(self):
    if
    print(f'Student Name')










st1 = BracuStudent("Afif", "Mirpur")
print("1===========================")
st2 = BracuStudent("Shanto", "Motijheel")
st3 = BracuStudent("Taskin", "Mirpur")
st1.show_details()
st2.show_details()
print("2===========================")
st3.show_details()
print("3===========================")
bus1 = BracuBus("Mirpur")
bus2 = BracuBus("Azimpur", 5)
bus1.show_details()
bus2.show_details()
print("4===========================")
st2.get_pass()
st3.get_pass()
print("5===========================")
st2.show_details()
st3.show_details()
print("6===========================")
bus1.board()
print("7===========================")
bus1.board(st1, st2)
print("8===========================")
st1.get_pass()
st2.home = "Mirpur"
st1.show_details()
st2.show_details()
print("9===========================")
bus1.board(st1, st2, st3)
print("10===========================")
bus1.show_details()

# %%
#theory assignment 2 task1

#task6


class Train:
  numberOfTrains=0

  def __init__(self,name,*args):
    self.name=name
    self.args=args
    self.obj=[]
    self.des=[]
    #Train.numberOfTrains+=1


    print(f'Welcome aboard on {self.name}')
    print(f'Start: {self.args[0]}')
    print(f'Destination: {self.args[len(self.args)-1]}')
    self.des+=list(args)
    print(self.des)
    Train.numberOfTrains+=1

  def addPassenger(self,*reference):
    #self.obj=[]
    self.reference=reference
    #self.obj=[]
    self.obj+=list(reference)
    if len(self.reference)<2:
      print(f'{self.reference[0].name} welcome aboard')

    elif len(self.reference)==2:
      print(f'{self.reference[0].name} welcome aboard')
      print(f'{self.reference[1].name} welcome aboard')
      #print(f'{self.reference[2].name} welcome aboard')

    else:
      print(f'{self.reference[0].name} welcome aboard')
      print(f'{self.reference[1].name} welcome aboard')
      print(f'{self.reference[2].name} welcome aboard')


  def numberOfTrains(self):
    return Train.numberOfTrains

  def allPassengerDetails(self):
    #a=Passenger(self)
    l=len(self.des)
    end2=self.des[l-1]
    start=''
    end=''
    start2=''
    end2=''
    fair1=0
    fair2=0
    fair3=0

    # for i in self.des:
    #   for j in self.obj:
    #     if self.obj[j].start==None and self.obj[j].end==None:
    #       fair




    for i in range(len(self.obj)):
      for j in range(len(self.des)):

        if self.obj[i].start!=None and self.obj[i].end!=None : #hinata
          for k in self.des:
            if k==self.obj[i].start:
              start=k
              break

          for l in self.des:
            if l==self.obj[i].end:
              end=l
              break

          for m in range(len(self.des)):
            if self.des[m]==self.obj[i].start:
              x=self.des[m:len(self.des)]

          for n in range(len(x)):
            if x[n]==end:
              break

            else:
              fair3+=100



          print(f'Name: {self.obj[i].name}, Start: {start},Destination:{end},Fair:${fair3}')
          break
        elif self.obj[i].start!=None and self.obj[i].end==None and self.obj[i].start==self.des[j]: #sasuke
          for f in range(len(self.des)):
            if self.des[f]==self.obj[i].start:
              start2=self.des[f:len(self.des)]

          for g in start2:
            if g==start2[-1]:
              break

            else:
              fair2+=100


          print(f'Name: {self.obj[i].name}, Start: {self.des[j]},Destination: {end2},Fair:${fair2}')
          fair2=0
          break

        elif self.obj[i].start==None and self.obj[i].end==None: #naruto
          start2=self.des[0]
          end2=self.des[-1]

          for e in range(len(self.des)):
            if self.des[e]==end2:
              break
            else:
              fair1+=100
          print(f'Name: {self.obj[i].name}, Start: {self.des[j]},Destination:{end2},Fare:${fair1}')
          fair1=0
          break


    l=0
    self.des=[]
    self.obj=[]




class Passenger:
  numberOfPassenger=0
  def __init__(self,name,start=None,end=None):
    #self.desti=desti
    self.name=name
    self.start=start
    self.end=end
    Passenger.numberOfPassenger+=1
    #print(f'{self.name} welcome abroad')

  def numberOfPassenger(self):

    return Passenger.numberOfPassenger


t1 = Train('T1-Express','New York','Manhattan','Brooklyn','Boston')
print("1========================")
p1 =Passenger("Naruto")
p1.setStart("New York")
p1.setDestination("Boston")
t1.addPassenger(p1)
p2 = Passenger("Sasuke","Manhattan")
p3 = Passenger("Hinata","Manhattan","Brooklyn")
print("2========================")
t1.addPassenger(p2,p3)
print("3========================")
print("Train.numberOfTrains()")
print(Passenger.numberOfPassenger())
print("3========================")
t1.allPassengerDetails()
print("4========================")
t2 = Train('Europe-Express','London','Paris','Brussels','Turkey')
print("5========================")
p4 =Passenger("Max")
p5 = Passenger("Eleven")
p5.setTravelDetails("London","Brussels")
p6 = Passenger("Mike","Brussels")
t2.addPassenger(p4,p5,p6)
print("6========================")
t2.allPassengerDetails()
print("6========================")
print("Train.numberOfTrains()")
print(Passenger.numberOfPassenger())
# Out:
# Welcome aboard on T1-Express
# Start: New York
# Destination: Boston
# ['New York', 'Manhattan', 'Brooklyn', 'Boston']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-41f5780b6a3e> in <cell line: 148>()
#     146
#     147
# --> 148 t1 = Train('T1-Express','New York','Manhattan','Brooklyn','Boston')
#     149 print("1========================")
#     150 p1 =Passenger("Naruto")
#
# <ipython-input-4-41f5780b6a3e> in __init__(self, name, *args)
#      20     self.des+=list(args)
#      21     print(self.des)
# ---> 22     Train.numberOfTrains+=1
#      23
#      24   def addPassenger(self,*reference):
#
# TypeError: unsupported operand type(s) for +=: 'function' and 'int'

# %%
a=['New York','Manhattan','Brooklyn','Boston']
b=[]

b+=a

print(b)
# Out:
# ['New York', 'Manhattan', 'Brooklyn', 'Boston']
